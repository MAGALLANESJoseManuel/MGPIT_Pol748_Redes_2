# %% [markdown]
# <center><img src="https://i.imgur.com/YNtjmbq.png" width="800"></center>

# %% [markdown]
# # Práctica 2 – Exploración de Redes

# %% [markdown]
# En el año 2018, Quinten Dol sugirió a los usuarios de Twitter seguir a estas celebridades de la Tecnologia local:

# %%
from IPython.display import IFrame
IFrame('https://www.builtinseattle.com/2018/08/06/50-seattle-tech-twitter-accounts-to-follow', 800, 350)
# Out:
#         <iframe
#             width="800"
#             height="350"
#             src="https://www.builtinseattle.com/2018/08/06/50-seattle-tech-twitter-accounts-to-follow"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Aunque proponía 50 _influencers_, sólo hay 46 activos en X (antes Twitter). Se construyó una red para ver si entre ellos se seguían, y esto tenemos:

# %%
IFrame('https://docs.google.com/spreadsheets/d/e/2PACX-1vQaaNQb2frjnlt0fPSBQhp5tNydB0a9ibp98sblBn6OfvGd8vsx8cfHb4w8Cm_qC3EIeYFby_zNQBoK/pubhtml', 800, 350)
# Out:
#         <iframe
#             width="800"
#             height="350"
#             src="https://docs.google.com/spreadsheets/d/e/2PACX-1vQaaNQb2frjnlt0fPSBQhp5tNydB0a9ibp98sblBn6OfvGd8vsx8cfHb4w8Cm_qC3EIeYFby_zNQBoK/pubhtml"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## Data para la sesión
#
# Para esta sesión, los datos del archivo **SeattleTop** puedes descargarlos en _tu_ carpeta **data** desde este [enlace](https://drive.google.com/drive/folders/1QXy0RwgNUBryirnVx0-_-rfr3WZxSld5?usp=sharing).
# </div>

# %% [markdown]
# # Exploración Básica de la red
#
# Como ya sabemos, la red se arma con la **adjacency matrix** o la **edgelist**. Hagámoslo nuevamente:

# %%
# librerias necesarias
import networkx as nx
import pandas as pd

# link a GoogleDrive como un Excel
linkGoogle="https://docs.google.com/spreadsheets/d/e/2PACX-1vQaaNQb2frjnlt0fPSBQhp5tNydB0a9ibp98sblBn6OfvGd8vsx8cfHb4w8Cm_qC3EIeYFby_zNQBoK/pub?output=xlsx"

# leyendo archivo de red
adjacency=pd.read_excel(linkGoogle,   
                        index_col=0,  # la columna '0' guarda los nombres
                        sheet_name='adjacency') # la tabla tiene este nombre

# creando red dirigida
TopFromAdjacency=nx.from_pandas_adjacency(adjacency,create_using=nx.DiGraph)

# %% [markdown]
# El objeto **TopFromAdjacency** contiene a la red creada. Esta red es **dirigida** (DiGraph):

# %%
type(TopFromAdjacency)
# Out:
# networkx.classes.digraph.DiGraph

# %% [markdown]
# ¿Tendremos algun _influencer_ que no siga a otro ni sea seguido por otro?

# %%
list(nx.isolates(TopFromAdjacency))
# Out:
# []

# %% [markdown]
# De ahi que la red no mostrará nodos aislados:

# %%
nx.draw(TopFromAdjacency, with_labels=True,edge_color='grey',width=0.3,node_color='yellow')

# %% [markdown]
# Por lo general, podemos explorar la red de dos maneras:
#
# 1. A nivel de red en total.
# 2. A nivel de cada actor (nodo).

# %% [markdown]
# ## Exporando a nivel de red

# %% [markdown]
# Recordemos la cantidad de nodos y enlaces de la red.

# %%
# nodos , #enlaces
len(TopFromAdjacency.nodes),len(TopFromAdjacency.edges)
# Out:
# (46, 588)

# %% [markdown]
# Una de las primeras interrogantes, es saber si cada nodo puede conectarse con otro nodo. Para que ello sucede, teniendo en cuenta que la red es dirigida, debe haber un **path** o camino (sequencia de flechas) entre todo par de nodos de la red. Si esto fuera así, se debe verificar que la red es **strongly_connected**:

# %%
nx.is_strongly_connected(TopFromAdjacency)
# Out:
# False

# %% [markdown]
# El resultado anterior indica que hay algunos nodos que no pueden ser alcanzados por otros nodos.
#
# Así, dos conceptos clave para entedender las conexiones en las redes son:
#
# 1. Distancia
# 2. Alcanzabilidad o **reachability**
# 2. Densidad o **Density**:
#
# La **distance** se entiende como la cantidad de _edges_ que separan un par de nodos. Como entre algun par de nodos puede haber muchas distancias, calculemos el **geodesico** es la distancia más corta entre dos nodos:

# %%
# calcular los geodesicos para cada nodo
geodesics = dict(nx.all_pairs_shortest_path_length(TopFromAdjacency))

# formatear geodesicos como matriz
MatrixGeo = [[geodesics.get(n, {}).get(m, 0)  for m in TopFromAdjacency.nodes] for n in TopFromAdjacency.nodes]

# formatear matriz de geodesicos como dataframe
MatrixGeo_DF=pd.DataFrame(MatrixGeo,index=TopFromAdjacency.nodes, columns=TopFromAdjacency.nodes,dtype=np.int32)

#tenemos
MatrixGeo_DF
# Out:
#                  rachelerman  mattmcilwain  DaveParkerSEA  toddbishop  \
# rachelerman                0             1              1           1
# mattmcilwain               2             0              2           1
# DaveParkerSEA              1             2              0           1
# toddbishop                 1             1              1           0
# ashannstew                 1             1              2           1
# LeslieFeinzaig             1             2              1           1
# akipman                    2             3              3           2
# matt_oppy                  1             1              1           1
# gilbert                    1             2              2           2
# juliesandler               1             1              1           1
# BradSmi                    1             2              2           1
# crashdev                   1             2              2           1
# ShaunaCausey               1             1              1           1
# john_gabbert               1             2              2           1
# moniguzman                 1             2              2           1
# mattmday                   1             1              2           1
# Rich_Barton                2             2              2           2
# daryn                      1             2              2           1
# lovelletters               1             1              1           1
# etzioni                    1             1              1           1
# MissDestructo              1             1              1           1
# heatherredman              1             2              1           1
# danshapiro                 1             2              2           2
# medinism                   2             2              3           2
# KieranSnyder               1             2              2           1
# hadip                      2             2              2           1
# RajSinghSeattle            2             1              2           2
# funcOfJoe                  2             1              2           2
# kirbywinfield              2             2              1           2
# stevesi                    2             2              2           1
# Ryanintheus                1             2              1           1
# sonalpmane                 1             2              2           2
# SoGulley                   2             2              1           1
# 2morrowknight              0             0              0           0
# jinman                     2             2              1           1
# tarah                      0             0              0           0
# Jenerationy                1             2              2           1
# lanctot                    2             2              2           1
# Kristen_Hammy              2             1              2           1
# nhuntwalker                2             3              1           2
# eugenio_pace               0             0              0           0
# JenMsft                    2             3              3           2
# PeterHamilton              2             2              2           1
# sarahstood                 2             2              2           1
# mcolacurcio                2             2              2           1
# marybethlambert            1             2              2           1
#
#                  ashannstew  LeslieFeinzaig  akipman  matt_oppy  gilbert  \
# rachelerman               1               1        1          1        1
# mattmcilwain              2               2        2          2        1
# DaveParkerSEA             1               1        2          1        1
# toddbishop                1               1        1          1        1
# ashannstew                0               1        2          1        1
# LeslieFeinzaig            1               0        2          1        2
# akipman                   3               3        0          3        3
# matt_oppy                 1               1        2          0        1
# gilbert                   2               2        2          2        0
# juliesandler              1               1        2          1        1
# BradSmi                   2               2        1          2        2
# crashdev                  2               2        2          1        2
# ShaunaCausey              2               1        2          1        2
# john_gabbert              2               2        2          1        2
# moniguzman                1               1        2          2        1
# mattmday                  1               2        1          2        2
# Rich_Barton               3               2        3          3        2
# daryn                     2               2        2          2        1
# lovelletters              1               1        2          1        2
# etzioni                   2               2        2          2        1
# MissDestructo             2               1        1          2        1
# heatherredman             1               1        2          2        1
# danshapiro                2               2        2          2        2
# medinism                  2               3        2          2        3
# KieranSnyder              2               1        2          2        2
# hadip                     2               2        2          2        2
# RajSinghSeattle           2               2        2          1        2
# funcOfJoe                 2               2        3          2        2
# kirbywinfield             2               1        3          2        1
# stevesi                   2               1        2          2        1
# Ryanintheus               2               1        2          2        2
# sonalpmane                2               1        2          2        2
# SoGulley                  2               1        2          2        2
# 2morrowknight             0               0        0          0        0
# jinman                    2               2        2          2        2
# tarah                     0               0        0          0        0
# Jenerationy               1               2        2          2        1
# lanctot                   1               2        2          2        1
# Kristen_Hammy             2               2        2          2        2
# nhuntwalker               2               2        2          2        2
# eugenio_pace              0               0        0          0        0
# JenMsft                   3               2        1          3        2
# PeterHamilton             2               2        2          2        2
# sarahstood                2               2        2          2        2
# mcolacurcio               2               1        2          2        2
# marybethlambert           2               2        2          2        2
#
#                  juliesandler  ...  Jenerationy  lanctot  Kristen_Hammy  \
# rachelerman                 1  ...            2        2              2
# mattmcilwain                1  ...            3        2              2
# DaveParkerSEA               1  ...            1        1              1
# toddbishop                  1  ...            2        1              1
# ashannstew                  1  ...            2        2              2
# LeslieFeinzaig              1  ...            2        2              2
# akipman                     3  ...            4        3              3
# matt_oppy                   1  ...            1        2              1
# gilbert                     1  ...            3        2              2
# juliesandler                0  ...            2        2              1
# BradSmi                     2  ...            3        2              2
# crashdev                    1  ...            2        2              1
# ShaunaCausey                1  ...            1        1              1
# john_gabbert                1  ...            2        2              2
# moniguzman                  1  ...            1        1              2
# mattmday                    1  ...            2        2              2
# Rich_Barton                 2  ...            3        3              2
# daryn                       1  ...            2        2              2
# lovelletters                1  ...            2        2              1
# etzioni                     1  ...            2        2              2
# MissDestructo               1  ...            2        2              2
# heatherredman               1  ...            2        2              1
# danshapiro                  2  ...            2        2              2
# medinism                    2  ...            3        3              2
# KieranSnyder                1  ...            3        2              1
# hadip                       2  ...            3        2              2
# RajSinghSeattle             2  ...            2        3              2
# funcOfJoe                   1  ...            3        3              2
# kirbywinfield               1  ...            2        1              2
# stevesi                     2  ...            2        2              1
# Ryanintheus                 2  ...            1        2              2
# sonalpmane                  1  ...            2        2              2
# SoGulley                    1  ...            1        2              1
# 2morrowknight               0  ...            0        0              0
# jinman                      2  ...            2        2              2
# tarah                       0  ...            0        0              0
# Jenerationy                 1  ...            0        2              2
# lanctot                     2  ...            2        0              2
# Kristen_Hammy               1  ...            2        2              0
# nhuntwalker                 2  ...            2        2              2
# eugenio_pace                0  ...            0        0              0
# JenMsft                     2  ...            3        3              2
# PeterHamilton               2  ...            1        2              2
# sarahstood                  1  ...            2        2              2
# mcolacurcio                 2  ...            2        2              1
# marybethlambert             2  ...            2        2              2
#
#                  nhuntwalker  eugenio_pace  JenMsft  PeterHamilton  \
# rachelerman                2             2        2              2
# mattmcilwain               3             3        2              2
# DaveParkerSEA              1             1        2              2
# toddbishop                 2             2        1              1
# ashannstew                 3             2        2              2
# LeslieFeinzaig             2             2        2              2
# akipman                    4             4        3              3
# matt_oppy                  2             1        2              1
# gilbert                    2             3        2              3
# juliesandler               2             2        2              2
# BradSmi                    3             3        2              2
# crashdev                   3             1        2              2
# ShaunaCausey               2             2        2              1
# john_gabbert               3             2        2              2
# moniguzman                 2             3        2              2
# mattmday                   2             3        2              2
# Rich_Barton                3             3        2              3
# daryn                      3             3        2              2
# lovelletters               2             2        2              2
# etzioni                    2             2        2              2
# MissDestructo              2             2        2              1
# heatherredman              2             2        2              2
# danshapiro                 2             3        2              3
# medinism                   3             2        3              3
# KieranSnyder               1             3        2              2
# hadip                      3             2        2              2
# RajSinghSeattle            3             2        2              2
# funcOfJoe                  2             3        2              3
# kirbywinfield              2             2        2              3
# stevesi                    2             2        1              2
# Ryanintheus                1             2        1              2
# sonalpmane                 2             2        2              2
# SoGulley                   1             2        2              1
# 2morrowknight              0             0        0              0
# jinman                     2             2        2              2
# tarah                      0             0        0              0
# Jenerationy                2             2        2              1
# lanctot                    3             3        2              2
# Kristen_Hammy              2             2        2              2
# nhuntwalker                0             2        1              2
# eugenio_pace               0             0        0              0
# JenMsft                    2             3        0              3
# PeterHamilton              3             2        2              0
# sarahstood                 2             2        2              2
# mcolacurcio                3             3        2              1
# marybethlambert            3             3        2              2
#
#                  sarahstood  mcolacurcio  marybethlambert
# rachelerman               2            2                2
# mattmcilwain              2            2                3
# DaveParkerSEA             2            2                2
# toddbishop                1            1                2
# ashannstew                2            2                2
# LeslieFeinzaig            2            1                2
# akipman                   3            3                4
# matt_oppy                 2            2                2
# gilbert                   3            3                3
# juliesandler              2            2                2
# BradSmi                   2            2                3
# crashdev                  2            2                2
# ShaunaCausey              1            1                1
# john_gabbert              2            2                2
# moniguzman                1            1                2
# mattmday                  2            2                3
# Rich_Barton               3            3                3
# daryn                     2            2                2
# lovelletters              2            2                2
# etzioni                   2            2                2
# MissDestructo             2            2                2
# heatherredman             2            1                1
# danshapiro                2            2                3
# medinism                  3            3                3
# KieranSnyder              2            2                3
# hadip                     2            2                3
# RajSinghSeattle           3            2                2
# funcOfJoe                 3            3                3
# kirbywinfield             3            2                2
# stevesi                   2            2                2
# Ryanintheus               1            2                2
# sonalpmane                2            2                2
# SoGulley                  2            2                2
# 2morrowknight             0            0                0
# jinman                    2            2                2
# tarah                     0            0                0
# Jenerationy               2            2                2
# lanctot                   2            2                2
# Kristen_Hammy             2            2                2
# nhuntwalker               2            3                3
# eugenio_pace              0            0                0
# JenMsft                   3            3                3
# PeterHamilton             2            2                2
# sarahstood                0            2                2
# mcolacurcio               2            0                2
# marybethlambert           2            2                0
#
# [46 rows x 46 columns]

# %% [markdown]
# La diagonal es cero, pero si alguna fila o columna presenta ceros, nos indica que no hay camino entre esos dos nodos.
#
# De lo anterior, podemos obtener la **reachability matrix**, que nos informa si hay conexión entre nodos:

# %%
MatrixReach_DF=(MatrixGeo_DF>0).replace({True:1,False:0})
MatrixReach_DF
# Out:
#                  rachelerman  mattmcilwain  DaveParkerSEA  toddbishop  \
# rachelerman                0             1              1           1
# mattmcilwain               1             0              1           1
# DaveParkerSEA              1             1              0           1
# toddbishop                 1             1              1           0
# ashannstew                 1             1              1           1
# LeslieFeinzaig             1             1              1           1
# akipman                    1             1              1           1
# matt_oppy                  1             1              1           1
# gilbert                    1             1              1           1
# juliesandler               1             1              1           1
# BradSmi                    1             1              1           1
# crashdev                   1             1              1           1
# ShaunaCausey               1             1              1           1
# john_gabbert               1             1              1           1
# moniguzman                 1             1              1           1
# mattmday                   1             1              1           1
# Rich_Barton                1             1              1           1
# daryn                      1             1              1           1
# lovelletters               1             1              1           1
# etzioni                    1             1              1           1
# MissDestructo              1             1              1           1
# heatherredman              1             1              1           1
# danshapiro                 1             1              1           1
# medinism                   1             1              1           1
# KieranSnyder               1             1              1           1
# hadip                      1             1              1           1
# RajSinghSeattle            1             1              1           1
# funcOfJoe                  1             1              1           1
# kirbywinfield              1             1              1           1
# stevesi                    1             1              1           1
# Ryanintheus                1             1              1           1
# sonalpmane                 1             1              1           1
# SoGulley                   1             1              1           1
# 2morrowknight              0             0              0           0
# jinman                     1             1              1           1
# tarah                      0             0              0           0
# Jenerationy                1             1              1           1
# lanctot                    1             1              1           1
# Kristen_Hammy              1             1              1           1
# nhuntwalker                1             1              1           1
# eugenio_pace               0             0              0           0
# JenMsft                    1             1              1           1
# PeterHamilton              1             1              1           1
# sarahstood                 1             1              1           1
# mcolacurcio                1             1              1           1
# marybethlambert            1             1              1           1
#
#                  ashannstew  LeslieFeinzaig  akipman  matt_oppy  gilbert  \
# rachelerman               1               1        1          1        1
# mattmcilwain              1               1        1          1        1
# DaveParkerSEA             1               1        1          1        1
# toddbishop                1               1        1          1        1
# ashannstew                0               1        1          1        1
# LeslieFeinzaig            1               0        1          1        1
# akipman                   1               1        0          1        1
# matt_oppy                 1               1        1          0        1
# gilbert                   1               1        1          1        0
# juliesandler              1               1        1          1        1
# BradSmi                   1               1        1          1        1
# crashdev                  1               1        1          1        1
# ShaunaCausey              1               1        1          1        1
# john_gabbert              1               1        1          1        1
# moniguzman                1               1        1          1        1
# mattmday                  1               1        1          1        1
# Rich_Barton               1               1        1          1        1
# daryn                     1               1        1          1        1
# lovelletters              1               1        1          1        1
# etzioni                   1               1        1          1        1
# MissDestructo             1               1        1          1        1
# heatherredman             1               1        1          1        1
# danshapiro                1               1        1          1        1
# medinism                  1               1        1          1        1
# KieranSnyder              1               1        1          1        1
# hadip                     1               1        1          1        1
# RajSinghSeattle           1               1        1          1        1
# funcOfJoe                 1               1        1          1        1
# kirbywinfield             1               1        1          1        1
# stevesi                   1               1        1          1        1
# Ryanintheus               1               1        1          1        1
# sonalpmane                1               1        1          1        1
# SoGulley                  1               1        1          1        1
# 2morrowknight             0               0        0          0        0
# jinman                    1               1        1          1        1
# tarah                     0               0        0          0        0
# Jenerationy               1               1        1          1        1
# lanctot                   1               1        1          1        1
# Kristen_Hammy             1               1        1          1        1
# nhuntwalker               1               1        1          1        1
# eugenio_pace              0               0        0          0        0
# JenMsft                   1               1        1          1        1
# PeterHamilton             1               1        1          1        1
# sarahstood                1               1        1          1        1
# mcolacurcio               1               1        1          1        1
# marybethlambert           1               1        1          1        1
#
#                  juliesandler  ...  Jenerationy  lanctot  Kristen_Hammy  \
# rachelerman                 1  ...            1        1              1
# mattmcilwain                1  ...            1        1              1
# DaveParkerSEA               1  ...            1        1              1
# toddbishop                  1  ...            1        1              1
# ashannstew                  1  ...            1        1              1
# LeslieFeinzaig              1  ...            1        1              1
# akipman                     1  ...            1        1              1
# matt_oppy                   1  ...            1        1              1
# gilbert                     1  ...            1        1              1
# juliesandler                0  ...            1        1              1
# BradSmi                     1  ...            1        1              1
# crashdev                    1  ...            1        1              1
# ShaunaCausey                1  ...            1        1              1
# john_gabbert                1  ...            1        1              1
# moniguzman                  1  ...            1        1              1
# mattmday                    1  ...            1        1              1
# Rich_Barton                 1  ...            1        1              1
# daryn                       1  ...            1        1              1
# lovelletters                1  ...            1        1              1
# etzioni                     1  ...            1        1              1
# MissDestructo               1  ...            1        1              1
# heatherredman               1  ...            1        1              1
# danshapiro                  1  ...            1        1              1
# medinism                    1  ...            1        1              1
# KieranSnyder                1  ...            1        1              1
# hadip                       1  ...            1        1              1
# RajSinghSeattle             1  ...            1        1              1
# funcOfJoe                   1  ...            1        1              1
# kirbywinfield               1  ...            1        1              1
# stevesi                     1  ...            1        1              1
# Ryanintheus                 1  ...            1        1              1
# sonalpmane                  1  ...            1        1              1
# SoGulley                    1  ...            1        1              1
# 2morrowknight               0  ...            0        0              0
# jinman                      1  ...            1        1              1
# tarah                       0  ...            0        0              0
# Jenerationy                 1  ...            0        1              1
# lanctot                     1  ...            1        0              1
# Kristen_Hammy               1  ...            1        1              0
# nhuntwalker                 1  ...            1        1              1
# eugenio_pace                0  ...            0        0              0
# JenMsft                     1  ...            1        1              1
# PeterHamilton               1  ...            1        1              1
# sarahstood                  1  ...            1        1              1
# mcolacurcio                 1  ...            1        1              1
# marybethlambert             1  ...            1        1              1
#
#                  nhuntwalker  eugenio_pace  JenMsft  PeterHamilton  \
# rachelerman                1             1        1              1
# mattmcilwain               1             1        1              1
# DaveParkerSEA              1             1        1              1
# toddbishop                 1             1        1              1
# ashannstew                 1             1        1              1
# LeslieFeinzaig             1             1        1              1
# akipman                    1             1        1              1
# matt_oppy                  1             1        1              1
# gilbert                    1             1        1              1
# juliesandler               1             1        1              1
# BradSmi                    1             1        1              1
# crashdev                   1             1        1              1
# ShaunaCausey               1             1        1              1
# john_gabbert               1             1        1              1
# moniguzman                 1             1        1              1
# mattmday                   1             1        1              1
# Rich_Barton                1             1        1              1
# daryn                      1             1        1              1
# lovelletters               1             1        1              1
# etzioni                    1             1        1              1
# MissDestructo              1             1        1              1
# heatherredman              1             1        1              1
# danshapiro                 1             1        1              1
# medinism                   1             1        1              1
# KieranSnyder               1             1        1              1
# hadip                      1             1        1              1
# RajSinghSeattle            1             1        1              1
# funcOfJoe                  1             1        1              1
# kirbywinfield              1             1        1              1
# stevesi                    1             1        1              1
# Ryanintheus                1             1        1              1
# sonalpmane                 1             1        1              1
# SoGulley                   1             1        1              1
# 2morrowknight              0             0        0              0
# jinman                     1             1        1              1
# tarah                      0             0        0              0
# Jenerationy                1             1        1              1
# lanctot                    1             1        1              1
# Kristen_Hammy              1             1        1              1
# nhuntwalker                0             1        1              1
# eugenio_pace               0             0        0              0
# JenMsft                    1             1        0              1
# PeterHamilton              1             1        1              0
# sarahstood                 1             1        1              1
# mcolacurcio                1             1        1              1
# marybethlambert            1             1        1              1
#
#                  sarahstood  mcolacurcio  marybethlambert
# rachelerman               1            1                1
# mattmcilwain              1            1                1
# DaveParkerSEA             1            1                1
# toddbishop                1            1                1
# ashannstew                1            1                1
# LeslieFeinzaig            1            1                1
# akipman                   1            1                1
# matt_oppy                 1            1                1
# gilbert                   1            1                1
# juliesandler              1            1                1
# BradSmi                   1            1                1
# crashdev                  1            1                1
# ShaunaCausey              1            1                1
# john_gabbert              1            1                1
# moniguzman                1            1                1
# mattmday                  1            1                1
# Rich_Barton               1            1                1
# daryn                     1            1                1
# lovelletters              1            1                1
# etzioni                   1            1                1
# MissDestructo             1            1                1
# heatherredman             1            1                1
# danshapiro                1            1                1
# medinism                  1            1                1
# KieranSnyder              1            1                1
# hadip                     1            1                1
# RajSinghSeattle           1            1                1
# funcOfJoe                 1            1                1
# kirbywinfield             1            1                1
# stevesi                   1            1                1
# Ryanintheus               1            1                1
# sonalpmane                1            1                1
# SoGulley                  1            1                1
# 2morrowknight             0            0                0
# jinman                    1            1                1
# tarah                     0            0                0
# Jenerationy               1            1                1
# lanctot                   1            1                1
# Kristen_Hammy             1            1                1
# nhuntwalker               1            1                1
# eugenio_pace              0            0                0
# JenMsft                   1            1                1
# PeterHamilton             1            1                1
# sarahstood                0            1                1
# mcolacurcio               1            0                1
# marybethlambert           1            1                0
#
# [46 rows x 46 columns]

# %% [markdown]
# Notese que la fila de _2morrowknight_ está llena de ceros, déjame mostrarte la red ego de este actor (su vecindario de conexiones):

# %%
nx.draw(nx.ego_graph(TopFromAdjacency,'2morrowknight',undirected=True),with_labels=True)

# %% [markdown]
# Se nota que _2morrowknight_ no tiene flechas que salen (out) de éste. Así, a _2morrowknight_ se le puede alcanzar, pero este no puede alcanzar a otros. La matriz muestrs dos más, que podemos hallarlos así:

# %%
Seattle_connComp = sorted(nx.strongly_connected_components(TopFromAdjacency), key=len, reverse=False)
Seattle_connComp[:3]
# Out:
# [{'tarah'}, {'2morrowknight'}, {'eugenio_pace'}]

# %%
nodesPositions=nx.spring_layout(TopFromAdjacency,k=0.5)
ConnectedComponents =(TopFromAdjacency.subgraph(c).copy() for c in nx.strongly_connected_components(TopFromAdjacency))
color_map = ['red' if node in Seattle_connComp[3] else 'green' for node in TopFromAdjacency.nodes()]
nx.draw(TopFromAdjacency,nodesPositions,node_color=color_map,with_labels=True)

# %% [markdown]
# Un concepto que se desprende del _reachability_ es la **reciprocidad**:

# %%
nx.overall_reciprocity(TopFromAdjacency)
# Out:
# 0.6632653061224489

# %%
nx.diameter(TopFromAdjacency.subgraph(Seattle_connComp[3]))
# Out:
# 4

# %% [markdown]
# ¿Que tan densa es la red?

# %%
nx.density(TopFromAdjacency)
# Out:
# 0.28405797101449276

# %% [markdown]
# ### Consultas a nivel de actor

# %% [markdown]
# ¿Cuántas conexiones tienen los actores?

# %%
pd.concat([pd.DataFrame.from_dict(nx.out_degree_centrality(TopFromAdjacency),
                                  orient='index',
                                  columns=['OutDegree']),
           pd.DataFrame.from_dict(nx.in_degree_centrality(TopFromAdjacency),
                                  orient='index',
                                  columns=['InDegree']),
           pd.DataFrame.from_dict(nx.closeness_centrality(TopFromAdjacency.reverse()),
                                  orient='index',
                                  columns=['closeness_out']),
           pd.DataFrame.from_dict(nx.closeness_centrality(TopFromAdjacency),
                                  orient='index',
                                  columns=['closeness_in']),
           pd.DataFrame.from_dict(nx.betweenness_centrality(TopFromAdjacency),
                                  orient='index',
                                  columns=['betweenness'])],axis=1)
# Out:
#                  OutDegree  InDegree  closeness_out  closeness_in  betweenness
# rachelerman       0.577778  0.533333       0.703125      0.653333     0.049295
# mattmcilwain      0.200000  0.288889       0.529412      0.529730     0.006917
# DaveParkerSEA     0.800000  0.333333       0.833333      0.544444     0.055038
# toddbishop        0.866667  0.688889       0.882353      0.739623     0.155510
# ashannstew        0.333333  0.266667       0.584416      0.522667     0.003663
# LeslieFeinzaig    0.355556  0.400000       0.608108      0.576471     0.010229
# akipman           0.022222  0.133333       0.340909      0.483951     0.000063
# matt_oppy         0.577778  0.244444       0.703125      0.515789     0.017005
# gilbert           0.155556  0.355556       0.473684      0.560000     0.003672
# juliesandler      0.577778  0.577778       0.703125      0.664407     0.043588
# BradSmi           0.177778  0.266667       0.511364      0.544444     0.030744
# crashdev          0.355556  0.466667       0.592105      0.612500     0.036575
# ShaunaCausey      0.622222  0.511111       0.725806      0.622222     0.058534
# john_gabbert      0.133333  0.155556       0.523256      0.490000     0.000112
# moniguzman        0.511111  0.488889       0.661765      0.622222     0.038562
# mattmday          0.266667  0.222222       0.555556      0.522667     0.015020
# Rich_Barton       0.066667  0.422222       0.416667      0.603077     0.001954
# daryn             0.222222  0.155556       0.542169      0.478049     0.002392
# lovelletters      0.533333  0.488889       0.681818      0.622222     0.020971
# etzioni           0.311111  0.355556       0.592105      0.576471     0.020220
# MissDestructo     0.511111  0.355556       0.671642      0.560000     0.029941
# heatherredman     0.577778  0.533333       0.703125      0.642623     0.047620
# danshapiro        0.088889  0.355556       0.483871      0.568116     0.001221
# medinism          0.044444  0.200000       0.409091      0.509091     0.000733
# KieranSnyder      0.244444  0.444444       0.548780      0.603077     0.024244
# hadip             0.133333  0.466667       0.511364      0.612500     0.009550
# RajSinghSeattle   0.155556  0.377778       0.505618      0.576471     0.005627
# funcOfJoe         0.155556  0.066667       0.468750      0.445455     0.000364
# kirbywinfield     0.200000  0.377778       0.535714      0.576471     0.007193
# stevesi           0.400000  0.533333       0.625000      0.642623     0.053774
# Ryanintheus       0.311111  0.200000       0.592105      0.483951     0.009775
# sonalpmane        0.266667  0.177778       0.562500      0.490000     0.000611
# SoGulley          0.488889  0.155556       0.661765      0.466667     0.007855
# 2morrowknight     0.000000  0.044444       0.000000      0.384008     0.000000
# jinman            0.133333  0.066667       0.535714      0.435556     0.000028
# tarah             0.000000  0.177778       0.000000      0.489153     0.000000
# Jenerationy       0.266667  0.155556       0.569620      0.445455     0.002122
# lanctot           0.244444  0.111111       0.548780      0.461176     0.000988
# Kristen_Hammy     0.200000  0.266667       0.548780      0.536986     0.001776
# nhuntwalker       0.155556  0.088889       0.517241      0.408333     0.001929
# eugenio_pace      0.000000  0.066667       0.000000      0.415039     0.000000
# JenMsft           0.088889  0.088889       0.424528      0.478049     0.001511
# PeterHamilton     0.177778  0.155556       0.542169      0.461176     0.001166
# sarahstood        0.177778  0.088889       0.542169      0.445455     0.000397
# mcolacurcio       0.266667  0.111111       0.555556      0.455814     0.000767
# marybethlambert   0.111111  0.044444       0.511364      0.408333     0.000036

# %% [markdown]
# ### Pasos previos en UCINET
#
# Para comenzar, no olvide indicar que **data** es el folder por defecto. Abramos en UCINET la matriz de adyacencia como en la sesión anterior (usando el **Matrix Editor**):
#
#
# <img src="https://i.imgur.com/5CcgRfx.png" width="800"/>
#
# La matriz de adyacencia se abrirá en el editor. Guardela en el formato de UCINET:
#
#
# <img src="https://i.imgur.com/5RIrcza.png" width="800"/>
#
# A esta altura, ya debes tener un archivo de UCINET con esta red.
#
#
# <img src="https://i.imgur.com/2lZCLEg.png" width="800"/>
#
#
# Ahora, como tenemos atributos, usemos el **DL editor** para abrirlo:
#
#
#
# <img src="https://i.imgur.com/n9pKeC2.png" width="800"/>
#
# Una vez abierto, guardalo como archivo UCINET también, pero indica que es de atributos en el nombre del archivo. Nota que estamos usando la opción _Matrix_ en el formato de datos:
#
#
#
# <img src="https://i.imgur.com/7RR7Igy.png" width="800"/>

# %% [markdown]
# Ahora, ya tenemos los dos archivos que necesitamos para visualizar en **NETDRAW**.

# %% [markdown]
# # Visualizando en NETDRAW
#
# Como se sabe, UCINET usa NetDraw para dibujar. Como tenemos archivo de RED y de ATRIBUTO debemos seguir  pasos particulares en cada caso:
#
# <img src="https://i.imgur.com/pt1QwcC.png" width="800"/>
#
#
# 1) La red se abre con la carpeta que muestra una _U_. Proceda.
# 2) Los atributos se abren con la carpeta que muestra una _A_. Proceda.
#
# Si siguió los pasos, debe ver algo así:
#
#
# <img src="https://i.imgur.com/fMZeC6c.png" width="800"/>

# %% [markdown]
# <div class="alert-success">
#
# ## Ejercicio 1
#
# * Si tu red y sus atributos ya está en NETDRAW, ve a **PROPERTIES** en el menú principal.
# * Enfocate en los _NODOS_, y selecciona _SIMBOLOS_. En _simbolos_ verás 4 opciones. Piensa en estas tres: Color / Size / Shape.
#
# <img src="https://i.imgur.com/mGnEjxg.png" width="800"/>
#
# * Cada una de esas tres opciones puedes personalizarlas usando los atributos que tienes.
#
# ### ¿Donde usarías el atributo **male** y el **followers**?
#
#
# <br>
# </div>

# %% [markdown]
# ## Exploración básica de la red

# %%
nx.is_directed(TopFromAdjacency)

# %%
sorted(d for n, d in TopFromAdjacency.out_degree())

# %%
pd.DataFrame(TopFromAdjacency.out_degree())
